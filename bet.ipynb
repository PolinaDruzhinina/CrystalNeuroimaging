# %%
import nipype.interfaces.fsl as fsl
from nilearn.plotting import plot_anat
import os

# %%
# skullstrip = BET(in_file="/data/ds000114/sub-01/ses-test/anat/sub-01_ses-test_T1w.nii.gz",
#                  out_file="/output/T1w_nipype_bet.nii.gz",
#                  mask=True,
#                  reduce_bias = True,
#                  remove_eyes = True)
# res = skullstrip.run()

# %%
plot_anat('/home/datasets/adni/data/100307.nii', title='original',
          display_mode='ortho', dim=-1, draw_cross=False, annotate=False)

# %%
PATH_TO_MRI = '/home/datasets/HCP_T1'
PATH_TO_OUT = '/home/datasets/HCP_T1_fsl'
i = 0 

for sub in os.listdir(PATH_TO_MRI):
    if len(sub) == 6:
        if os.path.exists('{}/{}/unprocessed/3T/T1w_MPR1/{}_3T_T1w_MPR1.nii.gz'.format(PATH_TO_MRI,sub, sub)):
            full_path = '{}/{}/unprocessed/3T/T1w_MPR1/{}_3T_T1w_MPR1.nii.gz'.format(PATH_TO_MRI, sub, sub)
            out_path = '{}/{}/unprocessed/3T/T1w_MPR1/{}_3T_T1w_MPR1.nii.gz'.format(PATH_TO_OUT, sub, sub)
            skullstrip = fsl.BET(in_file=full_path,
                 out_file=out_path,
                 mask=True,
                 reduce_bias = True)
            res = skullstrip.run()
            i=+1
            print(i)
# Out:
# 201214-15:01:28,94 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# OSErrorTraceback (most recent call last)
# <ipython-input-6-8d5682abbc9c> in <module>
#      11                  mask=True,
#      12                  reduce_bias = True)
# ---> 13             res = skullstrip.run()
#      14             i=+1
#      15             print(i)
#
# /usr/local/lib/python3.6/dist-packages/nipype/interfaces/base/core.py in run(self, cwd, ignore_exception, **inputs)
#     395         try:
#     396             runtime = self._pre_run_hook(runtime)
# --> 397             runtime = self._run_interface(runtime)
#     398             runtime = self._post_run_hook(runtime)
#     399             outputs = self.aggregate_outputs(runtime)
#
# /usr/local/lib/python3.6/dist-packages/nipype/interfaces/fsl/preprocess.py in _run_interface(self, runtime)
#     160         # in stderr and if it's set, then update the returncode
# ...
