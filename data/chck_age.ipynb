# %%
import numpy as np
import functools
import matplotlib.pyplot as plt
import pandas as pd
import os
import pathlib

# %%
PATH_TO_MRI = '/home/datasets/HCP_T1_fsl/HCP_T1_pm'
data_dir = pathlib.Path('/home/datasets/adni')
behavioral_path = os.path.join(data_dir / 'unrestricted_hcp_freesurfer.csv')
hcp_type = 'MPR1'

# %%
age = pd.read_csv(behavioral_path)

# %%
age
# Out:
#       Subject Gender Release  FS_InterCranial_Vol  FS_BrainSeg_Vol  \
# 0      100206      M    S900         1.864518e+06        1406924.0
# 1      100307      F      Q1         1.512540e+06        1109710.0
# 2      100408      M      Q3         1.684117e+06        1280171.0
# 3      100610      M    S900         1.816044e+06        1321362.0
# 4      101006      F    S500         1.437868e+06        1053766.0
# ...       ...    ...     ...                  ...              ...
# 1108   992774      M      Q2         1.519017e+06        1136193.0
# 1109   993675      F    S900         1.408199e+06        1037401.0
# 1110   994273      M    S500         1.738013e+06        1234076.0
# 1111   995174      M   S1200         1.745369e+06        1253571.0
# 1112   996782      F    S900         1.793902e+06        1301212.0
#
#       FS_BrainSeg_Vol_No_Vent  FS_BrainSeg_Vol_No_Vent_Surf  FS_LCort_GM_Vol  \
# 0                   1389007.0                  1.386836e+06           304488
# ...

# %%
a = pd.read_csv('/home/datasets/adni/unrestricted_plina007polina_1_12_2021_15_8_41.csv')

# %%
a
# Out:
#       Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0      100004    S900         Q06      M  22-25             False         0
# 1      100206    S900         Q11      M  26-30              True         1
# 2      100307      Q1         Q01      F  26-30              True         1
# 3      100408      Q3         Q03      M  31-35              True         1
# 4      100610    S900         Q08      M  26-30              True         2
# ...       ...     ...         ...    ...    ...               ...       ...
# 1201   992774      Q2         Q02      M  31-35              True         2
# 1202   993675    S900         Q09      F  26-30              True         2
# 1203   994273    S500         Q06      M  26-30              True         1
# 1204   995174   S1200         Q13      M  22-25             False         1
# 1205   996782    S900         Q08      F  26-30              True         2
#
# ...

# %%
age = age['Subject'].to_list()
a = a['Subject'].to_list()

# %%
num = []
for i in a:
    if i not in age:
        num.append(i)
print(len(num))
# Out:
# 93

# %%
#skull_strip
indir = os.listdir('/home/datasets/HCP_T1_fsl/HCP_T1_pm')
notina = []
for each in indir:
    each = each[:6]
    if int(each) not in a:
            notina.append(each)
print(len(notina))
# Out:
# 0

# %%
a['Age'].unique()
# Out:
# array(['22-25', '26-30', '31-35', '36+'], dtype=object)

# %%
a.loc[(a['Age']=='22-25') | (a['Age']=='26-30'), 'lower_30'] = 1
a.loc[(a['Age']=='31-35') | (a['Age']=='36+'), 'lower_30'] = 0

# %%
lower= a.loc[a['lower_30']==1]

# %%
len(lower)
# Out:
# 774

# %%
len(a)
# Out:
# 1206

# %%
1206-774
# Out:
# 432

# %%
a
# Out:
#       Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0      100004    S900         Q06      M  22-25             False         0
# 1      100206    S900         Q11      M  26-30              True         1
# 2      100307      Q1         Q01      F  26-30              True         1
# 3      100408      Q3         Q03      M  31-35              True         1
# 4      100610    S900         Q08      M  26-30              True         2
# ...       ...     ...         ...    ...    ...               ...       ...
# 1201   992774      Q2         Q02      M  31-35              True         2
# 1202   993675    S900         Q09      F  26-30              True         2
# 1203   994273    S500         Q06      M  26-30              True         1
# 1204   995174   S1200         Q13      M  22-25             False         1
# 1205   996782    S900         Q08      F  26-30              True         2
#
# ...
